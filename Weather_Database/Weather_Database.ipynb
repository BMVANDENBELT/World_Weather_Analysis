# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the Latitude and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 720

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    #generally, it isn't a good idea to add the pass statement to the except block. Ideally, we want to handle or catch each
    #error as it happens and do something specific like add another try block or print out the error.

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gouyave
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | kieta
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | severo-kurilsk
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | san patricio
# Processing Record 9 of Set 1 | forquilhinha
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 1 | meulaboh
# Processing Record 14 of Set 1 | carnarvon
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | vostok
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | bengkulu
# Processing Record 19 of Set 1 | kuusamo
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | bethel
# Processing Record 23 of Set 1 | sawara
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | port augusta
# Processing Record 28 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | koumac
# Processing Record 31 of Set 1 | buckingham
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | buloh kasap
# Processing Record 35 of Set 1 | san cristobal
# Processing Record 36 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 1 | kushima
# Processing Record 38 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 1 | cockburn town
# Processing Record 40 of Set 1 | puerto colombia
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | port macquarie
# Processing Record 43 of Set 1 | mishelevka
# Processing Record 44 of Set 1 | vila franca do campo
# Processing Record 45 of Set 1 | kupang
# Processing Record 46 of Set 1 | port hedland
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | helong
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | brae
# Processing Record 2 of Set 2 | nuuk
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | karratha
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 2 | dunedin
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | lata
# Processing Record 12 of Set 2 | smidovich
# Processing Record 13 of Set 2 | tasiilaq
# Processing Record 14 of Set 2 | bandarbeyla
# Processing Record 15 of Set 2 | diamantino
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | marawi
# Processing Record 19 of Set 2 | mobaye
# Processing Record 20 of Set 2 | arica
# Processing Record 21 of Set 2 | mitchelstown
# Processing Record 22 of Set 2 | evinayong
# Processing Record 23 of Set 2 | ambarawa
# Processing Record 24 of Set 2 | murdochville
# Processing Record 25 of Set 2 | tignere
# Processing Record 26 of Set 2 | henties bay
# Processing Record 27 of Set 2 | dali
# Processing Record 28 of Set 2 | mitsamiouli
# Processing Record 29 of Set 2 | santa maria
# Processing Record 30 of Set 2 | ulladulla
# Processing Record 31 of Set 2 | atascadero
# Processing Record 32 of Set 2 | reriutaba
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | kuching
# Processing Record 35 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 2 | viedma
# Processing Record 37 of Set 2 | bamnet narong
# Processing Record 38 of Set 2 | haines junction
# Processing Record 39 of Set 2 | genhe
# Processing Record 40 of Set 2 | beloha
# Processing Record 41 of Set 2 | verkhoyansk
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | gagino
# Processing Record 45 of Set 2 | mabaruma
# Processing Record 46 of Set 2 | vanavara
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 2 | ancud
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | ilhabela
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | santo augusto
# Processing Record 4 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 3 | wilmington
# Processing Record 6 of Set 3 | port arthur
# Processing Record 7 of Set 3 | sistranda
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | lodja
# Processing Record 11 of Set 3 | leh
# Processing Record 12 of Set 3 | pisco
# Processing Record 13 of Set 3 | kununurra
# Processing Record 14 of Set 3 | ostrovnoy
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | dikson
# Processing Record 17 of Set 3 | tarauaca
# Processing Record 18 of Set 3 | lodwar
# Processing Record 19 of Set 3 | lasa
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | clyde river
# Processing Record 23 of Set 3 | bambous virieux
# Processing Record 24 of Set 3 | upernavik
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | roebourne
# Processing Record 27 of Set 3 | prado
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | artvin
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | airai
# Processing Record 33 of Set 3 | sao filipe
# Processing Record 34 of Set 3 | kapaa
# Processing Record 35 of Set 3 | moanda
# Processing Record 36 of Set 3 | kaitangata
# Processing Record 37 of Set 3 | harper
# Processing Record 38 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 3 | necochea
# Processing Record 40 of Set 3 | saskylakh
# Processing Record 41 of Set 3 | breznita-motru
# Processing Record 42 of Set 3 | sibolga
# Processing Record 43 of Set 3 | galle
# Processing Record 44 of Set 3 | olinda
# Processing Record 45 of Set 3 | raudeberg
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | kinshasa
# Processing Record 48 of Set 3 | alindao
# Processing Record 49 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 50 of Set 3 | hayden
# Processing Record 1 of Set 4 | ciudad bolivar
# Processing Record 2 of Set 4 | nhulunbuy
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | teeli
# Processing Record 5 of Set 4 | voskresenskoye
# Processing Record 6 of Set 4 | qaanaaq
# Processing Record 7 of Set 4 | medicine hat
# Processing Record 8 of Set 4 | quang ngai
# Processing Record 9 of Set 4 | klaksvik
# Processing Record 10 of Set 4 | port blair
# Processing Record 11 of Set 4 | strezhevoy
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | tuscaloosa
# Processing Record 14 of Set 4 | lianran
# Processing Record 15 of Set 4 | vao
# Processing Record 16 of Set 4 | pacific grove
# Processing Record 17 of Set 4 | hobyo
# Processing Record 18 of Set 4 | verkhnetulomskiy
# Processing Record 19 of Set 4 | liwale
# Processing Record 20 of Set 4 | miranda
# Processing Record 21 of Set 4 | asyut
# Processing Record 22 of Set 4 | lorengau
# Processing Record 23 of Set 4 | kloulklubed
# Processing Record 24 of Set 4 | castro
# Processing Record 25 of Set 4 | codrington
# Processing Record 26 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 27 of Set 4 | camalu
# Processing Record 28 of Set 4 | burgeo
# Processing Record 29 of Set 4 | eureka
# Processing Record 30 of Set 4 | caravelas
# Processing Record 31 of Set 4 | esperance
# Processing Record 32 of Set 4 | cherskiy
# Processing Record 33 of Set 4 | deputatskiy
# Processing Record 34 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 4 | hohhot
# Processing Record 37 of Set 4 | touros
# Processing Record 38 of Set 4 | brownsville
# Processing Record 39 of Set 4 | cidreira
# Processing Record 40 of Set 4 | havelock
# Processing Record 41 of Set 4 | richards bay
# Processing Record 42 of Set 4 | tapaua
# City not found. Skipping...
# Processing Record 43 of Set 4 | lima
# Processing Record 44 of Set 4 | laguna
# Processing Record 45 of Set 4 | jinxiang
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | sitka
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | wawa
# Processing Record 50 of Set 4 | balikpapan
# Processing Record 1 of Set 5 | asau
# Processing Record 2 of Set 5 | ilulissat
# Processing Record 3 of Set 5 | kumla
# Processing Record 4 of Set 5 | kenai
# Processing Record 5 of Set 5 | hirara
# Processing Record 6 of Set 5 | puerto carreno
# Processing Record 7 of Set 5 | yumen
# Processing Record 8 of Set 5 | hithadhoo
# Processing Record 9 of Set 5 | katghora
# Processing Record 10 of Set 5 | vermilion
# Processing Record 11 of Set 5 | ninh binh
# Processing Record 12 of Set 5 | tonj
# Processing Record 13 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 5 | dukat
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | lalmohan
# Processing Record 17 of Set 5 | yithion
# City not found. Skipping...
# Processing Record 18 of Set 5 | pasighat
# Processing Record 19 of Set 5 | ixtapa
# Processing Record 20 of Set 5 | mayumba
# Processing Record 21 of Set 5 | chokurdakh
# Processing Record 22 of Set 5 | eydhafushi
# Processing Record 23 of Set 5 | pangnirtung
# Processing Record 24 of Set 5 | nagua
# Processing Record 25 of Set 5 | yulara
# Processing Record 26 of Set 5 | belaya gora
# Processing Record 27 of Set 5 | hamilton
# Processing Record 28 of Set 5 | nanortalik
# Processing Record 29 of Set 5 | inuvik
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | bousse
# Processing Record 32 of Set 5 | alamosa
# Processing Record 33 of Set 5 | umm lajj
# Processing Record 34 of Set 5 | iqaluit
# Processing Record 35 of Set 5 | sept-iles
# Processing Record 36 of Set 5 | tura
# Processing Record 37 of Set 5 | strelka
# Processing Record 38 of Set 5 | kabanjahe
# Processing Record 39 of Set 5 | konde
# Processing Record 40 of Set 5 | louis trichardt
# Processing Record 41 of Set 5 | chuy
# Processing Record 42 of Set 5 | amazar
# Processing Record 43 of Set 5 | isangel
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | shimoda
# Processing Record 46 of Set 5 | farafangana
# Processing Record 47 of Set 5 | tommot
# Processing Record 48 of Set 5 | mahina
# Processing Record 49 of Set 5 | soyo
# Processing Record 50 of Set 5 | redding
# Processing Record 1 of Set 6 | songjianghe
# Processing Record 2 of Set 6 | port moresby
# Processing Record 3 of Set 6 | beaverlodge
# Processing Record 4 of Set 6 | mehamn
# Processing Record 5 of Set 6 | khasan
# Processing Record 6 of Set 6 | khagrachari
# City not found. Skipping...
# Processing Record 7 of Set 6 | papara
# Processing Record 8 of Set 6 | samarai
# Processing Record 9 of Set 6 | paciran
# Processing Record 10 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 6 | bermejo
# Processing Record 12 of Set 6 | killybegs
# Processing Record 13 of Set 6 | khatanga
# Processing Record 14 of Set 6 | mendi
# Processing Record 15 of Set 6 | arlit
# Processing Record 16 of Set 6 | najran
# Processing Record 17 of Set 6 | broome
# Processing Record 18 of Set 6 | narsaq
# Processing Record 19 of Set 6 | juneau
# Processing Record 20 of Set 6 | kruisfontein
# Processing Record 21 of Set 6 | los andes
# Processing Record 22 of Set 6 | toktogul
# Processing Record 23 of Set 6 | belyy yar
# Processing Record 24 of Set 6 | bereda
# Processing Record 25 of Set 6 | dorado
# Processing Record 26 of Set 6 | asfi
# Processing Record 27 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 28 of Set 6 | goundam
# Processing Record 29 of Set 6 | urfa
# City not found. Skipping...
# Processing Record 30 of Set 6 | bara
# Processing Record 31 of Set 6 | neon karlovasion
# Processing Record 32 of Set 6 | dolores
# Processing Record 33 of Set 6 | camopi
# Processing Record 34 of Set 6 | petropavlovka
# Processing Record 35 of Set 6 | antofagasta
# Processing Record 36 of Set 6 | lagoa
# Processing Record 37 of Set 6 | nha trang
# Processing Record 38 of Set 6 | nicoya
# Processing Record 39 of Set 6 | auki
# Processing Record 40 of Set 6 | port-gentil
# Processing Record 41 of Set 6 | quatre cocos
# Processing Record 42 of Set 6 | porto novo
# Processing Record 43 of Set 6 | inhumas
# Processing Record 44 of Set 6 | horasan
# Processing Record 45 of Set 6 | maneadero
# Processing Record 46 of Set 6 | the valley
# Processing Record 47 of Set 6 | maniitsoq
# Processing Record 48 of Set 6 | pauini
# Processing Record 49 of Set 6 | kamloops
# Processing Record 50 of Set 6 | havre-saint-pierre
# Processing Record 1 of Set 7 | lubango
# Processing Record 2 of Set 7 | cabo san lucas
# Processing Record 3 of Set 7 | thompson
# Processing Record 4 of Set 7 | paita
# Processing Record 5 of Set 7 | wana
# Processing Record 6 of Set 7 | yar-sale
# Processing Record 7 of Set 7 | cedar city
# Processing Record 8 of Set 7 | geraldton
# Processing Record 9 of Set 7 | bensonville
# Processing Record 10 of Set 7 | norman wells
# Processing Record 11 of Set 7 | evanston
# Processing Record 12 of Set 7 | imbituba
# Processing Record 13 of Set 7 | opuwo
# Processing Record 14 of Set 7 | kahului
# Processing Record 15 of Set 7 | golfito
# Processing Record 16 of Set 7 | grindavik
# Processing Record 17 of Set 7 | kodinsk
# Processing Record 18 of Set 7 | margate
# Processing Record 19 of Set 7 | lincoln
# Processing Record 20 of Set 7 | tamiahua
# Processing Record 21 of Set 7 | half moon bay
# Processing Record 22 of Set 7 | limbuhan
# Processing Record 23 of Set 7 | katherine
# Processing Record 24 of Set 7 | te anau
# Processing Record 25 of Set 7 | ngama
# Processing Record 26 of Set 7 | kyren
# Processing Record 27 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 28 of Set 7 | uniontown
# Processing Record 29 of Set 7 | meadow lake
# Processing Record 30 of Set 7 | teguise
# Processing Record 31 of Set 7 | menongue
# Processing Record 32 of Set 7 | shirokiy
# Processing Record 33 of Set 7 | ligayan
# Processing Record 34 of Set 7 | rio tercero
# Processing Record 35 of Set 7 | macheng
# Processing Record 36 of Set 7 | sao jose da coroa grande
# Processing Record 37 of Set 7 | san francisco
# Processing Record 38 of Set 7 | constitucion
# Processing Record 39 of Set 7 | thongwa
# Processing Record 40 of Set 7 | paranaiba
# Processing Record 41 of Set 7 | flinders
# Processing Record 42 of Set 7 | sao joao da barra
# Processing Record 43 of Set 7 | quelimane
# Processing Record 44 of Set 7 | puro
# Processing Record 45 of Set 7 | saryg-sep
# Processing Record 46 of Set 7 | newport
# Processing Record 47 of Set 7 | biloela
# Processing Record 48 of Set 7 | rudsar
# Processing Record 49 of Set 7 | santa isabel do rio negro
# Processing Record 50 of Set 7 | souillac
# Processing Record 1 of Set 8 | alofi
# Processing Record 2 of Set 8 | san vicente
# Processing Record 3 of Set 8 | cabra
# Processing Record 4 of Set 8 | moyale
# Processing Record 5 of Set 8 | acapulco
# Processing Record 6 of Set 8 | salinopolis
# Processing Record 7 of Set 8 | coihueco
# Processing Record 8 of Set 8 | uthal
# Processing Record 9 of Set 8 | victoria
# Processing Record 10 of Set 8 | vestmannaeyjar
# Processing Record 11 of Set 8 | jiblah
# Processing Record 12 of Set 8 | vaitape
# Processing Record 13 of Set 8 | pundaguitan
# Processing Record 14 of Set 8 | sorong
# Processing Record 15 of Set 8 | coahuayana
# Processing Record 16 of Set 8 | bonito
# Processing Record 17 of Set 8 | astoria
# Processing Record 18 of Set 8 | palmeira das missoes
# Processing Record 19 of Set 8 | ishigaki
# Processing Record 20 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 8 | nalut
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | faya
# Processing Record 24 of Set 8 | iguatemi
# Processing Record 25 of Set 8 | myaundzha
# Processing Record 26 of Set 8 | morro bay
# Processing Record 27 of Set 8 | mayskiy
# Processing Record 28 of Set 8 | kingman
# Processing Record 29 of Set 8 | amberley
# Processing Record 30 of Set 8 | cortland
# Processing Record 31 of Set 8 | korla
# Processing Record 32 of Set 8 | luganville
# Processing Record 33 of Set 8 | gamba
# Processing Record 34 of Set 8 | miguel calmon
# Processing Record 35 of Set 8 | brigantine
# Processing Record 36 of Set 8 | tomatlan
# Processing Record 37 of Set 8 | ravar
# Processing Record 38 of Set 8 | baruun-urt
# Processing Record 39 of Set 8 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 40 of Set 8 | kutum
# Processing Record 41 of Set 8 | bahia blanca
# Processing Record 42 of Set 8 | port hardy
# Processing Record 43 of Set 8 | tilichiki
# Processing Record 44 of Set 8 | kavaratti
# Processing Record 45 of Set 8 | sola
# Processing Record 46 of Set 8 | hambantota
# Processing Record 47 of Set 8 | mantua
# Processing Record 48 of Set 8 | presidencia roque saenz pena
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | novikovo
# Processing Record 1 of Set 9 | kerouane
# Processing Record 2 of Set 9 | luwingu
# Processing Record 3 of Set 9 | nouadhibou
# Processing Record 4 of Set 9 | rudbar
# Processing Record 5 of Set 9 | waterboro
# Processing Record 6 of Set 9 | tuatapere
# Processing Record 7 of Set 9 | kavieng
# Processing Record 8 of Set 9 | salalah
# Processing Record 9 of Set 9 | waipawa
# Processing Record 10 of Set 9 | pozo colorado
# Processing Record 11 of Set 9 | dakar
# Processing Record 12 of Set 9 | puerto ayacucho
# Processing Record 13 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 14 of Set 9 | moose factory
# Processing Record 15 of Set 9 | kiunga
# Processing Record 16 of Set 9 | rio grande
# Processing Record 17 of Set 9 | halifax
# Processing Record 18 of Set 9 | misratah
# Processing Record 19 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 9 | mulanje
# Processing Record 21 of Set 9 | sawakin
# Processing Record 22 of Set 9 | laiyang
# Processing Record 23 of Set 9 | adrar
# Processing Record 24 of Set 9 | alice springs
# Processing Record 25 of Set 9 | bairiki
# Processing Record 26 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 9 | santa cruz cabralia
# Processing Record 28 of Set 9 | vicuna
# Processing Record 29 of Set 9 | keta
# Processing Record 30 of Set 9 | shenjiamen
# Processing Record 31 of Set 9 | elizabeth city
# Processing Record 32 of Set 9 | ornskoldsvik
# Processing Record 33 of Set 9 | benghazi
# Processing Record 34 of Set 9 | la asuncion
# Processing Record 35 of Set 9 | iznik
# Processing Record 36 of Set 9 | ierapetra
# Processing Record 37 of Set 9 | houma
# Processing Record 38 of Set 9 | kaina
# Processing Record 39 of Set 9 | limbang
# Processing Record 40 of Set 9 | wellington
# Processing Record 41 of Set 9 | nogliki
# Processing Record 42 of Set 9 | weilerswist
# Processing Record 43 of Set 9 | dalbandin
# Processing Record 44 of Set 9 | sorland
# Processing Record 45 of Set 9 | tezu
# Processing Record 46 of Set 9 | izhma
# Processing Record 47 of Set 9 | mugur-aksy
# Processing Record 48 of Set 9 | sur
# Processing Record 49 of Set 9 | saint-denis
# Processing Record 50 of Set 9 | obera
# Processing Record 1 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 2 of Set 10 | lamar
# Processing Record 3 of Set 10 | kampene
# Processing Record 4 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 5 of Set 10 | vagur
# Processing Record 6 of Set 10 | abiy adi
# City not found. Skipping...
# Processing Record 7 of Set 10 | lamu
# Processing Record 8 of Set 10 | ugoofaaru
# Processing Record 9 of Set 10 | san matias
# Processing Record 10 of Set 10 | todos santos
# Processing Record 11 of Set 10 | makungu
# Processing Record 12 of Set 10 | udachnyy
# Processing Record 13 of Set 10 | balaguer
# Processing Record 14 of Set 10 | dalvik
# Processing Record 15 of Set 10 | dingle
# Processing Record 16 of Set 10 | eenhana
# Processing Record 17 of Set 10 | shingu
# Processing Record 18 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 19 of Set 10 | barcelos
# Processing Record 20 of Set 10 | anadyr
# Processing Record 21 of Set 10 | vila do maio
# Processing Record 22 of Set 10 | feldkirchen-westerham
# Processing Record 23 of Set 10 | olden
# Processing Record 24 of Set 10 | simdega
# Processing Record 25 of Set 10 | uruacu
# Processing Record 26 of Set 10 | binzhou
# Processing Record 27 of Set 10 | college
# Processing Record 28 of Set 10 | cururupu
# Processing Record 29 of Set 10 | buin
# Processing Record 30 of Set 10 | bishop auckland
# Processing Record 31 of Set 10 | popondetta
# Processing Record 32 of Set 10 | kijang
# Processing Record 33 of Set 10 | ifanadiana
# Processing Record 34 of Set 10 | manta
# Processing Record 35 of Set 10 | labuhan
# Processing Record 36 of Set 10 | atambua
# Processing Record 37 of Set 10 | metu
# Processing Record 38 of Set 10 | rocha
# Processing Record 39 of Set 10 | aguimes
# Processing Record 40 of Set 10 | beringovskiy
# Processing Record 41 of Set 10 | valleyview
# Processing Record 42 of Set 10 | namatanai
# Processing Record 43 of Set 10 | kuytun
# Processing Record 44 of Set 10 | broken hill
# Processing Record 45 of Set 10 | aitape
# Processing Record 46 of Set 10 | qabis
# City not found. Skipping...
# Processing Record 47 of Set 10 | tahta
# Processing Record 48 of Set 10 | durant
# Processing Record 49 of Set 10 | yei
# Processing Record 50 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 1 of Set 11 | fairbanks
# Processing Record 2 of Set 11 | naron
# Processing Record 3 of Set 11 | saint-philippe
# Processing Record 4 of Set 11 | mercedes
# Processing Record 5 of Set 11 | chara
# Processing Record 6 of Set 11 | vila
# Processing Record 7 of Set 11 | vardo
# Processing Record 8 of Set 11 | fortuna
# Processing Record 9 of Set 11 | spiridonovka
# Processing Record 10 of Set 11 | antalaha
# Processing Record 11 of Set 11 | lubyany
# Processing Record 12 of Set 11 | omboue
# Processing Record 13 of Set 11 | katsuura
# Processing Record 14 of Set 11 | ponnani
# Processing Record 15 of Set 11 | bathsheba
# Processing Record 16 of Set 11 | kimbe
# Processing Record 17 of Set 11 | naze
# Processing Record 18 of Set 11 | kralendijk
# Processing Record 19 of Set 11 | novo aripuana
# Processing Record 20 of Set 11 | nome
# Processing Record 21 of Set 11 | duluth
# Processing Record 22 of Set 11 | lushunkou
# City not found. Skipping...
# Processing Record 23 of Set 11 | mwense
# Processing Record 24 of Set 11 | tuburan
# Processing Record 25 of Set 11 | natchez
# Processing Record 26 of Set 11 | rock springs
# Processing Record 27 of Set 11 | makat
# Processing Record 28 of Set 11 | tiksi
# Processing Record 29 of Set 11 | dhidhdhoo
# Processing Record 30 of Set 11 | chernyshevskiy
# Processing Record 31 of Set 11 | yerbogachen
# Processing Record 32 of Set 11 | maxixe
# Processing Record 33 of Set 11 | oranjemund
# Processing Record 34 of Set 11 | rio gallegos
# Processing Record 35 of Set 11 | santiago del estero
# Processing Record 36 of Set 11 | tabou
# Processing Record 37 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 11 | mastic beach
# Processing Record 40 of Set 11 | dondo
# Processing Record 41 of Set 11 | la libertad
# Processing Record 42 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 11 | sechura
# Processing Record 44 of Set 11 | okha
# Processing Record 45 of Set 11 | taywarah
# Processing Record 46 of Set 11 | portel
# Processing Record 47 of Set 11 | tavda
# Processing Record 48 of Set 11 | belmonte
# Processing Record 49 of Set 11 | bilma
# Processing Record 50 of Set 11 | sovetskiy
# Processing Record 1 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 12 | kyabram
# Processing Record 3 of Set 12 | mount gambier
# Processing Record 4 of Set 12 | mwinilunga
# Processing Record 5 of Set 12 | ganzhou
# Processing Record 6 of Set 12 | pierre
# Processing Record 7 of Set 12 | hay river
# Processing Record 8 of Set 12 | diffa
# Processing Record 9 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 12 | channel-port aux basques
# Processing Record 11 of Set 12 | andenes
# Processing Record 12 of Set 12 | derzhavinsk
# Processing Record 13 of Set 12 | erenhot
# Processing Record 14 of Set 12 | verkhniy baskunchak
# Processing Record 15 of Set 12 | pangoa
# Processing Record 16 of Set 12 | aklavik
# Processing Record 17 of Set 12 | aquiraz
# Processing Record 18 of Set 12 | bridgetown
# Processing Record 19 of Set 12 | morros
# Processing Record 20 of Set 12 | marsh harbour
# Processing Record 21 of Set 12 | gisborne
# Processing Record 22 of Set 12 | sumter
# Processing Record 23 of Set 12 | traunreut
# Processing Record 24 of Set 12 | ariquemes
# Processing Record 25 of Set 12 | itoman
# Processing Record 26 of Set 12 | tanout
# Processing Record 27 of Set 12 | we
# City not found. Skipping...
# Processing Record 28 of Set 12 | lavrentiya
# Processing Record 29 of Set 12 | dryden
# Processing Record 30 of Set 12 | coetupo
# City not found. Skipping...
# Processing Record 31 of Set 12 | kualakapuas
# Processing Record 32 of Set 12 | namtsy
# Processing Record 33 of Set 12 | matara
# Processing Record 34 of Set 12 | urucara
# Processing Record 35 of Set 12 | aginskoye
# Processing Record 36 of Set 12 | bako
# Processing Record 37 of Set 12 | oistins
# Processing Record 38 of Set 12 | fenoarivo
# Processing Record 39 of Set 12 | birao
# Processing Record 40 of Set 12 | mamallapuram
# Processing Record 41 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 12 | manono
# Processing Record 43 of Set 12 | mouzakion
# City not found. Skipping...
# Processing Record 44 of Set 12 | lompoc
# Processing Record 45 of Set 12 | hobbs
# Processing Record 46 of Set 12 | mackay
# Processing Record 47 of Set 12 | oparino
# Processing Record 48 of Set 12 | raymond
# Processing Record 49 of Set 12 | camocim
# Processing Record 50 of Set 12 | praia da vitoria
# Processing Record 1 of Set 13 | whitecourt
# Processing Record 2 of Set 13 | rockhampton
# Processing Record 3 of Set 13 | forestville
# Processing Record 4 of Set 13 | benjamin constant
# Processing Record 5 of Set 13 | amapa
# Processing Record 6 of Set 13 | lufkin
# Processing Record 7 of Set 13 | booue
# Processing Record 8 of Set 13 | pyaozerskiy
# Processing Record 9 of Set 13 | deoband
# Processing Record 10 of Set 13 | kolpashevo
# Processing Record 11 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 12 of Set 13 | chitungwiza
# Processing Record 13 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 13 | kangaatsiaq
# Processing Record 15 of Set 13 | vangaindrano
# Processing Record 16 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 17 of Set 13 | peleduy
# Processing Record 18 of Set 13 | alyangula
# Processing Record 19 of Set 13 | sioux lookout
# Processing Record 20 of Set 13 | villa union
# Processing Record 21 of Set 13 | polson
# Processing Record 22 of Set 13 | carberry
# Processing Record 23 of Set 13 | catamarca
# Processing Record 24 of Set 13 | maldonado
# Processing Record 25 of Set 13 | hopkinsville
# Processing Record 26 of Set 13 | abu samrah
# Processing Record 27 of Set 13 | vilyuysk
# Processing Record 28 of Set 13 | quetta
# Processing Record 29 of Set 13 | san-pedro
# Processing Record 30 of Set 13 | butiama
# Processing Record 31 of Set 13 | veraval
# Processing Record 32 of Set 13 | marsabit
# Processing Record 33 of Set 13 | weimar
# Processing Record 34 of Set 13 | kharitonovo
# Processing Record 35 of Set 13 | invermere
# Processing Record 36 of Set 13 | concepcion del oro
# Processing Record 37 of Set 13 | angul
# Processing Record 38 of Set 13 | manzil jamil
# City not found. Skipping...
# Processing Record 39 of Set 13 | sabinopolis
# Processing Record 40 of Set 13 | porto nacional
# Processing Record 41 of Set 13 | galveston
# Processing Record 42 of Set 13 | jiuquan
# Processing Record 43 of Set 13 | whitehorse
# Processing Record 44 of Set 13 | saint anthony
# Processing Record 45 of Set 13 | turayf
# Processing Record 46 of Set 13 | husavik
# Processing Record 47 of Set 13 | magadan
# Processing Record 48 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 49 of Set 13 | sai buri
# Processing Record 50 of Set 13 | tolaga bay
# Processing Record 1 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 14 | muzhi
# Processing Record 3 of Set 14 | namibe
# Processing Record 4 of Set 14 | novoye leushino
# Processing Record 5 of Set 14 | usinsk
# Processing Record 6 of Set 14 | gizo
# Processing Record 7 of Set 14 | oksovskiy
# Processing Record 8 of Set 14 | altay
# Processing Record 9 of Set 14 | sulangan
# Processing Record 10 of Set 14 | svetlyy
# Processing Record 11 of Set 14 | piaseczno
# Processing Record 12 of Set 14 | rognan
# Processing Record 13 of Set 14 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 14 | luang prabang
# Processing Record 15 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 16 of Set 14 | wanning
# Processing Record 17 of Set 14 | grindsted
# Processing Record 18 of Set 14 | carutapera
# Processing Record 19 of Set 14 | durango
# Processing Record 20 of Set 14 | malkangiri
# Processing Record 21 of Set 14 | boysun
# Processing Record 22 of Set 14 | dongsheng
# Processing Record 23 of Set 14 | muros
# Processing Record 24 of Set 14 | bontang
# Processing Record 25 of Set 14 | tutoia
# Processing Record 26 of Set 14 | gongzhuling
# Processing Record 27 of Set 14 | inirida
# Processing Record 28 of Set 14 | aden
# Processing Record 29 of Set 14 | northam
# Processing Record 30 of Set 14 | guadalupe
# Processing Record 31 of Set 14 | mpophomeni
# Processing Record 32 of Set 14 | comodoro rivadavia
# Processing Record 33 of Set 14 | bage
# Processing Record 34 of Set 14 | ulundi
# Processing Record 35 of Set 14 | taybad
# Processing Record 36 of Set 14 | katobu
# Processing Record 37 of Set 14 | penzance
# Processing Record 38 of Set 14 | muisne
# Processing Record 39 of Set 14 | nabire
# Processing Record 40 of Set 14 | mecca
# Processing Record 41 of Set 14 | byron bay
# Processing Record 42 of Set 14 | agadez
# Processing Record 43 of Set 14 | soria
# Processing Record 44 of Set 14 | takaka
# Processing Record 45 of Set 14 | fukue
# Processing Record 46 of Set 14 | kantunilkin
# Processing Record 47 of Set 14 | acari
# Processing Record 48 of Set 14 | praia
# Processing Record 49 of Set 14 | cortez
# Processing Record 50 of Set 14 | maloy
# Processing Record 1 of Set 15 | mitchell
# Processing Record 2 of Set 15 | batagay
# Processing Record 3 of Set 15 | awjilah
# Processing Record 4 of Set 15 | qibili
# City not found. Skipping...
# Processing Record 5 of Set 15 | sharjah
# Processing Record 6 of Set 15 | vilhena
# Processing Record 7 of Set 15 | kushmurun
# Processing Record 8 of Set 15 | pitimbu
# Processing Record 9 of Set 15 | carlyle
# Processing Record 10 of Set 15 | kamyshin
# Processing Record 11 of Set 15 | plettenberg bay
# Processing Record 12 of Set 15 | mae ramat
# Processing Record 13 of Set 15 | kiama
# Processing Record 14 of Set 15 | huanren
# Processing Record 15 of Set 15 | kirensk
# Processing Record 16 of Set 15 | kaka
# Processing Record 17 of Set 15 | tabukiniberu
# City not found. Skipping...
# Processing Record 18 of Set 15 | aubenas
# Processing Record 19 of Set 15 | troitsk
# Processing Record 20 of Set 15 | atar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Gouyave  12.1646  -61.7296     84.97        70          20
# 1          Hobart -42.8794  147.3294     44.46        81          20
# 2           Kieta  -6.2167  155.6333     79.70        82          82
# 3        Hermanus -34.4187   19.2345     53.80        80         100
# 4         Rikitea -23.1203 -134.9692     73.56        72          71
# 5  Severo-Kurilsk  50.6789  156.1250     57.27        91          70
# 6         Ushuaia -54.8000  -68.3000     40.66        65          75
# 7    San Patricio  28.0170  -97.5169     95.18        46          97
# 8    Forquilhinha -28.7475  -49.4722     50.23        90         100
# 9      Bredasdorp -34.5322   20.0403     53.01        88         100
#
#    Wind Speed Current Description Country                 Date
# 0       20.71          few clouds      GD  2022-08-18 20:38:54
# 1       12.66          few clouds      AU  2022-08-18 20:38:55
# 2        7.05          light rain      PG  2022-08-18 20:38:55
# 3        6.49     overcast clouds      ZA  2022-08-18 20:38:55
# 4       17.83       broken clouds      PF  2022-08-18 20:38:55
# 5        3.36       broken clouds      RU  2022-08-18 20:38:56
# 6        3.44       broken clouds      AR  2022-08-18 20:38:57
# 7       13.35     overcast clouds      US  2022-08-18 20:38:57
# 8        5.68     overcast clouds      BR  2022-08-18 20:38:58
# 9        6.91     overcast clouds      ZA  2022-08-18 20:38:58

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Gouyave      GD  12.1646  -61.7296     84.97        70          20
# 1          Hobart      AU -42.8794  147.3294     44.46        81          20
# 2           Kieta      PG  -6.2167  155.6333     79.70        82          82
# 3        Hermanus      ZA -34.4187   19.2345     53.80        80         100
# 4         Rikitea      PF -23.1203 -134.9692     73.56        72          71
# 5  Severo-Kurilsk      RU  50.6789  156.1250     57.27        91          70
# 6         Ushuaia      AR -54.8000  -68.3000     40.66        65          75
# 7    San Patricio      US  28.0170  -97.5169     95.18        46          97
# 8    Forquilhinha      BR -28.7475  -49.4722     50.23        90         100
# 9      Bredasdorp      ZA -34.5322   20.0403     53.01        88         100
#
#    Wind Speed Current Description
# 0       20.71          few clouds
# 1       12.66          few clouds
# 2        7.05          light rain
# 3        6.49     overcast clouds
# 4       17.83       broken clouds
# 5        3.36       broken clouds
# 6        3.44       broken clouds
# 7       13.35     overcast clouds
# 8        5.68     overcast clouds
# 9        6.91     overcast clouds
